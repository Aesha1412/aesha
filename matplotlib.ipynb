# %%
#pip install matplotlib on windows cmd/anaconda cmd
import matplotlib.pyplot as plt
import pandas as pd
# to see plots in the notebook
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2
print x
print y
# Out:
# [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5. ]
# [  0.     0.25   1.     2.25   4.     6.25   9.    12.25  16.    20.25  25.  ]

# %%
plt.plot(x, y, 'r') # 'r' is the color red
plt.xlabel('My X axis')
plt.ylabel('My Y axis')
plt.title('Plot title here')

# %%
plt.scatter(x,y)
plt.xlabel('My X axis')
plt.ylabel('My Y axis')
plt.title('Plot title here')

# %%
#histogram
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data,bins=30)
# Out:
# (array([ 4.,  2.,  2.,  5.,  3.,  7.,  2.,  3.,  1.,  1.,  2.,  4.,  3.,
#          1.,  4.,  8.,  4.,  3.,  3.,  6.,  2.,  4.,  4.,  2.,  7.,  3.,
#          3.,  2.,  3.,  2.]),
#  array([  19. ,   51.4,   83.8,  116.2,  148.6,  181. ,  213.4,  245.8,
#          278.2,  310.6,  343. ,  375.4,  407.8,  440.2,  472.6,  505. ,
#          537.4,  569.8,  602.2,  634.6,  667. ,  699.4,  731.8,  764.2,
#          796.6,  829. ,  861.4,  893.8,  926.2,  958.6,  991. ]),
#  <a list of 30 Patch objects>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]
# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);

# %%
#FURTHER READING
#The project web page for matplotlib.
#http://matplotlib.org/

# %%
#to draw multiple plots 
data = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv',index_col=0)
#index_col=0 is to omit the index col (@index 0)

# %%
fig, axes = plt.subplots(1, 3, sharey=True)#one row, 3 columns
data.plot(kind='scatter', x='TV', y='sales', ax=axes[0], figsize=(16, 8))
data.plot(kind='scatter', x='radio', y='sales', ax=axes[1])
data.plot(kind='scatter', x='newspaper', y='sales', ax=axes[2])
